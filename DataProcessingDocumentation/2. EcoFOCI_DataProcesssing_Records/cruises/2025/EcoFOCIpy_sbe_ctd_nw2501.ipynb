# %% [markdown]
# # Using EcoFOCIpy to process raw field data - NW2501
#
# *NW2501 - NBS*
#
# **Processed by Shaun Bell**
#
# A duplicate column of Fluorescence shows up
# ## CTD / Profile Data
#
# Basic workflow for each instrument grouping is *(initial archive level)*:
# - SBE workflow must happen first **done (performed on seperate windows system to convert to cnv)**
# - output initial files (pandas->csv) **ERDDAP NRT** when no meta data is added.  Good for quick analysis
#
# Other than hosting on an erddap server, the above can be done at sea
#
# For furthur processing, QC and archiving, the following tasks are to be done *(working or final data level)*:
# - Add metadata from cruise yaml files created from cast logs
# - apply any calibrations or corrections
#     + field corrections
#     + offsets
#     + spike analysis
#     + some QC were available... this would be old-school simple bounds mostly
# - save as CF netcdf via xarray or potentially csv file: so many of the steps above are optional
#     + **ERDDAP NRT** if no corrections, offsets or time bounds are applied but some meta data is (can be csv as this is useful at sea)
#     + **Working and awaiting QC** has no ERDDAP representation and is a holding spot
#     + **ERDDAP Final** fully calibrated, qc'd and populated with meta information
#
# Plot for preview and QC
# - TSSigma, TOXYChlor, TurbParTrans

# %%
import yaml
import glob

import EcoFOCIpy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import EcoFOCIpy.io.ncCFsave as ncCFsave
import EcoFOCIpy.metaconfig.load_config as load_config
import EcoFOCIpy.math.geotools as geotools

# %% [markdown]
# ## At Sea NRT Processing

# %%
sample_data_dir = '/Users/bell/ecoraid/2025/CTDcasts/nw2501/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'NW2501' #no hyphens
inst_meta_file = sample_data_dir+'logs/EMA_standard_CTD.yaml'
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %%
filename_list
# Out:
# ['/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd001.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd002.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd003.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd004.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd005.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd006.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd007.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd008.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd009.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd010.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd011.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd012.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd013.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd014.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd015.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd016.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd017.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd018.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd019.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd020.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd021.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd022.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd023.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd024.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd025.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd026.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd027.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd028.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd029.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd030.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd031.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd032.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd033.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd034.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd035.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd036.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd037.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd038.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd039.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd040.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd041.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd042.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd043.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd044.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/ctd045.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd001.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd002.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd003.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd004.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd005.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd006.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd007.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd008.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd009.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd010.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd011.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd012.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd013.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd014.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd015.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd016.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd017.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd018.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd019.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd020.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd021.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd022.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd023.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd024.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd025.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd026.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd027.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd028.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd029.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd030.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd031.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd032.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd033.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd034.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd035.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd036.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd037.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd038.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd039.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd040.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd041.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd042.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd043.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd044.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/dctd045.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd001.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd002.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd003.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd004.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd005.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd006.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd007.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd008.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd009.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd010.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd011.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd012.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd013.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd014.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd015.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd016.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd017.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd018.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd019.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd020.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd021.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd022.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd023.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd024.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd025.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd026.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd027.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd028.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd029.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd030.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd031.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd032.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd033.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd034.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd035.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd036.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd037.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd038.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd039.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd040.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd041.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd042.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd043.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd044.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/nw2501/rawconverted/uctd045.cnv']

# %%
cruise_header
# Out:
# {'ctd001.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NW2501 SBE911 CTD\\NW250101.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 6594\n',
#    '* Conductivity SN = 5057\n',
#    '* Number of Bytes Per Scan = 27\n',
#    '* Number of Voltage Words = 3\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 02 2025 23:16:02\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* delete word 8 from scan\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 02 2025 23:16:02\n',
#    '# nquan = 21\n',
#    '# nvalues = 19                          \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 8 = par/sat/log: PAR/Logarithmic, Satlantic [umol photons/m^2/sec]\n',
#    '# name 9 = sal00: Salinity, Practical [PSU]\n',
#    '# name 10 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 11 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 12 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 13 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 14 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 15 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 16 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 17 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 18 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 19 = nbin: number of scans per bin\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =  14.828470,  34.751705       \n',
#    '# span 1 =  28.092794,  34.638635       \n',
#    '# span 2 =     1.5087,     2.3062       \n',
#    '# span 3 =     1.8702,     2.0809       \n',
#    '# span 4 =     2.7970,     2.9720       \n',
#    '# span 5 =    10.4625,    10.4734       \n',
#    '# span 6 =    10.4829,    10.5695       \n',
#    '# span 7 =      5.000,     23.000       \n',
#    '# span 8 = 3.8759e-01, 1.4445e+02       \n',
#    '# span 9 =    12.3296,    31.1878       \n',
#    '# span 10 =    24.6998,    31.0653      \n',
#    '# span 11 =     6.4837,     8.2324      \n',
#    '# span 12 =     68.685,     79.898      \n',
#    '# span 13 =    198.614,    254.927      \n',
#    '# span 14 =     7.7916,     8.8198      \n',
#    '# span 15 =     84.983,     93.284      \n',
#    '# span 16 =    237.830,    270.570      \n',
#    '# span 17 =     9.2522,    23.8984      \n',
#    '# span 18 =    18.8468,    23.8014      \n',
#    '# span 19 =         15,         42      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Sep 02 2025 23:16:02 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="11" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6594</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32902716e-003</G>\n',
#    '#       <H>6.41296748e-004</H>\n',
#    '#       <I>2.24792144e-005</I>\n',
#    '#       <J>2.09037133e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5057</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02261783e+001</G>\n',
#    '#         <H>1.44216574e+000</H>\n',
#    '#         <I>-1.44249777e-003</I>\n',
#    '#         <J>1.83945074e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1467</SerialNumber>\n',
#    '#       <CalibrationDate>14-May-24</CalibrationDate>\n',
#    '#       <C1>-4.983324e+004</C1>\n',
#    '#       <C2>7.481707e-001</C2>\n',
#    '#       <C3>1.542490e-002</C3>\n',
#    '#       <D1>3.994200e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.011194e+001</T1>\n',
#    '#       <T2>-8.787910e-005</T2>\n',
#    '#       <T3>3.670550e-006</T3>\n',
#    '#       <T4>4.186210e-009</T4>\n',
#    '#       <Slope>0.99993591</Slope>\n',
#    '#       <Offset>-0.69285</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.279180e-002</AD590M>\n',
#    '#       <AD590B>-9.287340e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6597</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32855123e-003</G>\n',
#    '#       <H>6.37888659e-004</H>\n',
#    '#       <I>2.15927206e-005</I>\n',
#    '#       <J>1.98472116e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5058</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.00121804e+001</G>\n',
#    '#         <H>1.38193094e+000</H>\n',
#    '#         <I>-1.38157249e-003</I>\n',
#    '#         <J>1.71223075e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4138</SerialNumber>\n',
#    '#       <CalibrationDate>05-Jun-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>5.2342e-001</Soc>\n',
#    '#         <offset>-0.5284</offset>\n',
#    '#         <A>-3.5144e-003</A>\n',
#    '#         <B> 1.6216e-004</B>\n',
#    '#         <C>-2.8601e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0300</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4133</SerialNumber>\n',
#    '#       <CalibrationDate>30-May-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.1853e-001</Soc>\n',
#    '#         <offset>-0.7149</offset>\n',
#    '#         <A>-2.5264e-003</A>\n',
#    '#         <B> 2.5400e-005</B>\n',
#    '#         <C> 7.7465e-007</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.2100</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLRTD-6808</SerialNumber>\n',
#    '#       <CalibrationDate>6/3/2024</CalibrationDate>\n',
#    '#       <ScaleFactor>2.50000000e+001</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0320</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Logarithmic, Satlantic -->\n',
#    '#     <PARLog_SatlanticSensor SensorID="76" >\n',
#    '#       <SerialNumber>2146</SerialNumber>\n',
#    '#       <CalibrationDate>5/20/2024</CalibrationDate>\n',
#    '#       <a0>1.0656e+000</a0>\n',
#    '#       <a1>8.1157e-001</a1>\n',
#    '#       <Im>1.3589e+000</Im>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.0000e+000</Multiplier>\n',
#    '#     </PARLog_SatlanticSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Dec 11 2025 16:03:55, 7.26.7.129 [datcnv_vars = 9]\n',
#    '# datcnv_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.hex c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Dec 11 2025 16:03:56, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C prDM par/sat/log\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Dec 11 2025 16:03:57, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Dec 11 2025 16:03:57, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Dec 11 2025 16:03:57, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Dec 11 2025 16:03:58, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Dec 11 2025 16:03:58, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# binavg_date = Dec 11 2025 16:03:59, 7.26.7.129\n',
#    '# binavg_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250101.cnv\n',
#    '# binavg_bintype = decibars\n',
#    '# binavg_binsize = 1\n',
#    '# binavg_excl_bad_scans = yes\n',
#    '# binavg_skipover = 0\n',
#    '# binavg_omit = 0\n',
#    '# binavg_min_scans_bin = 1\n',
#    '# binavg_max_scans_bin = 2147483647\n',
#    '# binavg_surface_bin = no, min = 0.000, max = 0.000, value = 0.000\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 338,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'prDM',
#    8: 'par/sat/log',
#    9: 'sal00',
#    10: 'sal11',
#    11: 'sbeox0Mg/L',
#    12: 'sbeox0PS',
#    13: 'sbox0Mm/Kg',
#    14: 'sbeox1Mg/L',
#    15: 'sbeox1PS',
#    16: 'sbox1Mm/Kg',
#    17: 'sigma-t00',
#    18: 'sigma-t11',
#    19: 'nbin',
#    20: 'flag'},
#   'SYSTEMtime': 'Sep 02 2025 23:16:02',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []},
#  'ctd002.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NW2501 SBE911 CTD\\NW250102.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 6594\n',
#    '* Conductivity SN = 5057\n',
#    '* Number of Bytes Per Scan = 27\n',
#    '* Number of Voltage Words = 3\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 03 2025 16:09:03\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* delete word 8 from scan\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 03 2025 16:09:03\n',
#    '# nquan = 21\n',
#    '# nvalues = 32                          \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 8 = par/sat/log: PAR/Logarithmic, Satlantic [umol photons/m^2/sec]\n',
#    '# name 9 = sal00: Salinity, Practical [PSU]\n',
#    '# name 10 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 11 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 12 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 13 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 14 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 15 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 16 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 17 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 18 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 19 = nbin: number of scans per bin\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =   6.488546,  26.314609       \n',
#    '# span 1 =  31.914863,  32.521084       \n',
#    '# span 2 =     1.1569,     2.1042       \n',
#    '# span 3 =     1.5057,     1.5708       \n',
#    '# span 4 =     2.5207,     3.0797       \n',
#    '# span 5 =     7.4615,     8.4297       \n',
#    '# span 6 =     7.6346,     8.3689       \n',
#    '# span 7 =      5.000,     36.000       \n',
#    '# span 8 = 9.4135e-02, 5.4186e-01       \n',
#    '# span 9 =     5.4048,    24.9751       \n',
#    '# span 10 =    30.1218,    31.2622      \n',
#    '# span 11 =     5.1301,     6.1388      \n',
#    '# span 12 =     50.321,     53.671      \n',
#    '# span 13 =    157.638,    191.054      \n',
#    '# span 14 =     7.1393,     8.6327      \n',
#    '# span 15 =     73.432,     88.371      \n',
#    '# span 16 =    217.796,    263.470      \n',
#    '# span 17 =     4.1090,    19.4794      \n',
#    '# span 18 =    23.3934,    24.3770      \n',
#    '# span 19 =         17,         54      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Sep 03 2025 16:09:03 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="11" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6594</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32902716e-003</G>\n',
#    '#       <H>6.41296748e-004</H>\n',
#    '#       <I>2.24792144e-005</I>\n',
#    '#       <J>2.09037133e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5057</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02261783e+001</G>\n',
#    '#         <H>1.44216574e+000</H>\n',
#    '#         <I>-1.44249777e-003</I>\n',
#    '#         <J>1.83945074e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1467</SerialNumber>\n',
#    '#       <CalibrationDate>14-May-24</CalibrationDate>\n',
#    '#       <C1>-4.983324e+004</C1>\n',
#    '#       <C2>7.481707e-001</C2>\n',
#    '#       <C3>1.542490e-002</C3>\n',
#    '#       <D1>3.994200e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.011194e+001</T1>\n',
#    '#       <T2>-8.787910e-005</T2>\n',
#    '#       <T3>3.670550e-006</T3>\n',
#    '#       <T4>4.186210e-009</T4>\n',
#    '#       <Slope>0.99993591</Slope>\n',
#    '#       <Offset>-0.69285</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.279180e-002</AD590M>\n',
#    '#       <AD590B>-9.287340e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6597</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32855123e-003</G>\n',
#    '#       <H>6.37888659e-004</H>\n',
#    '#       <I>2.15927206e-005</I>\n',
#    '#       <J>1.98472116e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5058</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.00121804e+001</G>\n',
#    '#         <H>1.38193094e+000</H>\n',
#    '#         <I>-1.38157249e-003</I>\n',
#    '#         <J>1.71223075e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4138</SerialNumber>\n',
#    '#       <CalibrationDate>05-Jun-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>5.2342e-001</Soc>\n',
#    '#         <offset>-0.5284</offset>\n',
#    '#         <A>-3.5144e-003</A>\n',
#    '#         <B> 1.6216e-004</B>\n',
#    '#         <C>-2.8601e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0300</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4133</SerialNumber>\n',
#    '#       <CalibrationDate>30-May-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.1853e-001</Soc>\n',
#    '#         <offset>-0.7149</offset>\n',
#    '#         <A>-2.5264e-003</A>\n',
#    '#         <B> 2.5400e-005</B>\n',
#    '#         <C> 7.7465e-007</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.2100</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLRTD-6808</SerialNumber>\n',
#    '#       <CalibrationDate>6/3/2024</CalibrationDate>\n',
#    '#       <ScaleFactor>2.50000000e+001</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0320</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Logarithmic, Satlantic -->\n',
#    '#     <PARLog_SatlanticSensor SensorID="76" >\n',
#    '#       <SerialNumber>2146</SerialNumber>\n',
#    '#       <CalibrationDate>5/20/2024</CalibrationDate>\n',
#    '#       <a0>1.0656e+000</a0>\n',
#    '#       <a1>8.1157e-001</a1>\n',
#    '#       <Im>1.3589e+000</Im>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.0000e+000</Multiplier>\n',
#    '#     </PARLog_SatlanticSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Dec 11 2025 16:04:00, 7.26.7.129 [datcnv_vars = 9]\n',
#    '# datcnv_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.hex c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Dec 11 2025 16:04:01, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C prDM par/sat/log\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Dec 11 2025 16:04:02, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Dec 11 2025 16:04:02, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Dec 11 2025 16:04:02, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Dec 11 2025 16:04:03, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Dec 11 2025 16:04:03, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# binavg_date = Dec 11 2025 16:04:04, 7.26.7.129\n',
#    '# binavg_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250102.cnv\n',
#    '# binavg_bintype = decibars\n',
#    '# binavg_binsize = 1\n',
#    '# binavg_excl_bad_scans = yes\n',
#    '# binavg_skipover = 0\n',
#    '# binavg_omit = 0\n',
#    '# binavg_min_scans_bin = 1\n',
#    '# binavg_max_scans_bin = 2147483647\n',
#    '# binavg_surface_bin = no, min = 0.000, max = 0.000, value = 0.000\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 338,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'prDM',
#    8: 'par/sat/log',
#    9: 'sal00',
#    10: 'sal11',
#    11: 'sbeox0Mg/L',
#    12: 'sbeox0PS',
#    13: 'sbox0Mm/Kg',
#    14: 'sbeox1Mg/L',
#    15: 'sbeox1PS',
#    16: 'sbox1Mm/Kg',
#    17: 'sigma-t00',
#    18: 'sigma-t11',
#    19: 'nbin',
#    20: 'flag'},
#   'SYSTEMtime': 'Sep 03 2025 16:09:03',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []},
#  'ctd003.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NW2501 SBE911 CTD\\NW250103.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 6594\n',
#    '* Conductivity SN = 5057\n',
#    '* Number of Bytes Per Scan = 27\n',
#    '* Number of Voltage Words = 3\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 03 2025 20:48:49\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* delete word 8 from scan\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 03 2025 20:48:49\n',
#    '# nquan = 21\n',
#    '# nvalues = 51                          \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 8 = par/sat/log: PAR/Logarithmic, Satlantic [umol photons/m^2/sec]\n',
#    '# name 9 = sal00: Salinity, Practical [PSU]\n',
#    '# name 10 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 11 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 12 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 13 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 14 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 15 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 16 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 17 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 18 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 19 = nbin: number of scans per bin\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =  28.804440,  34.756893       \n',
#    '# span 1 =  28.802057,  34.754734       \n',
#    '# span 2 =     0.1010,     1.1506       \n',
#    '# span 3 =     1.9109,     2.3949       \n',
#    '# span 4 =     2.4523,     3.0713       \n',
#    '# span 5 =     2.7369,     9.9960       \n',
#    '# span 6 =     2.7356,     9.9958       \n',
#    '# span 7 =      1.000,     51.000       \n',
#    '# span 8 = 9.4134e-02, 2.6313e+02       \n',
#    '# span 9 =    31.5726,    31.7589       \n',
#    '# span 10 =    31.5893,    31.7573      \n',
#    '# span 11 =     7.8644,     8.8213      \n',
#    '# span 12 =     72.139,     95.636      \n',
#    '# span 13 =    239.723,    269.126      \n',
#    '# span 14 =     7.9300,     8.9143      \n',
#    '# span 15 =     72.633,     96.629      \n',
#    '# span 16 =    241.698,    271.965      \n',
#    '# span 17 =    24.3085,    25.3199      \n',
#    '# span 18 =    24.3069,    25.3187      \n',
#    '# span 19 =         23,         59      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Sep 03 2025 20:48:49 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="11" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6594</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32902716e-003</G>\n',
#    '#       <H>6.41296748e-004</H>\n',
#    '#       <I>2.24792144e-005</I>\n',
#    '#       <J>2.09037133e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5057</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02261783e+001</G>\n',
#    '#         <H>1.44216574e+000</H>\n',
#    '#         <I>-1.44249777e-003</I>\n',
#    '#         <J>1.83945074e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1467</SerialNumber>\n',
#    '#       <CalibrationDate>14-May-24</CalibrationDate>\n',
#    '#       <C1>-4.983324e+004</C1>\n',
#    '#       <C2>7.481707e-001</C2>\n',
#    '#       <C3>1.542490e-002</C3>\n',
#    '#       <D1>3.994200e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.011194e+001</T1>\n',
#    '#       <T2>-8.787910e-005</T2>\n',
#    '#       <T3>3.670550e-006</T3>\n',
#    '#       <T4>4.186210e-009</T4>\n',
#    '#       <Slope>0.99993591</Slope>\n',
#    '#       <Offset>-0.69285</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.279180e-002</AD590M>\n',
#    '#       <AD590B>-9.287340e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6597</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32855123e-003</G>\n',
#    '#       <H>6.37888659e-004</H>\n',
#    '#       <I>2.15927206e-005</I>\n',
#    '#       <J>1.98472116e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5058</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.00121804e+001</G>\n',
#    '#         <H>1.38193094e+000</H>\n',
#    '#         <I>-1.38157249e-003</I>\n',
#    '#         <J>1.71223075e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4138</SerialNumber>\n',
#    '#       <CalibrationDate>05-Jun-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>5.2342e-001</Soc>\n',
#    '#         <offset>-0.5284</offset>\n',
#    '#         <A>-3.5144e-003</A>\n',
#    '#         <B> 1.6216e-004</B>\n',
#    '#         <C>-2.8601e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0300</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4133</SerialNumber>\n',
#    '#       <CalibrationDate>30-May-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.1853e-001</Soc>\n',
#    '#         <offset>-0.7149</offset>\n',
#    '#         <A>-2.5264e-003</A>\n',
#    '#         <B> 2.5400e-005</B>\n',
#    '#         <C> 7.7465e-007</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.2100</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLRTD-6808</SerialNumber>\n',
#    '#       <CalibrationDate>6/3/2024</CalibrationDate>\n',
#    '#       <ScaleFactor>2.50000000e+001</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0320</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Logarithmic, Satlantic -->\n',
#    '#     <PARLog_SatlanticSensor SensorID="76" >\n',
#    '#       <SerialNumber>2146</SerialNumber>\n',
#    '#       <CalibrationDate>5/20/2024</CalibrationDate>\n',
#    '#       <a0>1.0656e+000</a0>\n',
#    '#       <a1>8.1157e-001</a1>\n',
#    '#       <Im>1.3589e+000</Im>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.0000e+000</Multiplier>\n',
#    '#     </PARLog_SatlanticSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Dec 11 2025 16:04:05, 7.26.7.129 [datcnv_vars = 9]\n',
#    '# datcnv_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.hex c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Dec 11 2025 16:04:07, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C prDM par/sat/log\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Dec 11 2025 16:04:08, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Dec 11 2025 16:04:08, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Dec 11 2025 16:04:08, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Dec 11 2025 16:04:09, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Dec 11 2025 16:04:09, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# binavg_date = Dec 11 2025 16:04:10, 7.26.7.129\n',
#    '# binavg_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250103.cnv\n',
# ...
#    '# filter_date = Dec 11 2025 16:07:36, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250144.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Dec 11 2025 16:07:36, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250144.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Dec 11 2025 16:07:37, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250144.cnv c:\\data\\ctd\\2025\\nw2501\\raw\\nw250144.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# split_date = Dec 11 2025 16:07:37, 7.26.7.129\n',
#    '# split_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250144.cnv\n',
#    '# split_excl_bad_scans = yes\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 329,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'prDM',
#    8: 'par/sat/log',
#    9: 'sal00',
#    10: 'sal11',
#    11: 'sbeox0Mg/L',
#    12: 'sbeox0PS',
#    13: 'sbox0Mm/Kg',
#    14: 'sbeox1Mg/L',
#    15: 'sbeox1PS',
#    16: 'sbox1Mm/Kg',
#    17: 'sigma-t00',
#    18: 'sigma-t11',
#    19: 'flag'},
#   'SYSTEMtime': 'Sep 18 2025 19:46:22',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []},
#  'uctd045.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NW2501 SBE911 CTD\\NW250145.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 6594\n',
#    '* Conductivity SN = 5057\n',
#    '* Number of Bytes Per Scan = 27\n',
#    '* Number of Voltage Words = 3\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 18 2025 23:21:30\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* delete word 8 from scan\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 18 2025 23:21:30\n',
#    '# nquan = 10\n',
#    '# nvalues = 2406                        \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 8 = par/sat/log: PAR/Logarithmic, Satlantic [umol photons/m^2/sec]\n',
#    '# name 9 = flag:  0.000e+00\n',
#    '# span 0 =   7.000000,  31.904055       \n',
#    '# span 1 =   4.000000,  31.902186       \n',
#    '# span 2 =     0.0000,     1.3673       \n',
#    '# span 3 =     0.0000,     2.4591       \n',
#    '# span 4 =     0.0000,     4.2467       \n',
#    '# span 5 =     8.0000,    10.2568       \n',
#    '# span 6 =     1.0000,    10.2584       \n',
#    '# span 7 =      1.547,     18.991       \n',
#    '# span 8 = 9.3784e-02, 3.0877e+02       \n',
#    '# span 9 = 0.0000e+00, 0.0000e+00       \n',
#    '# interval = seconds: 0.0416667\n',
#    '# start_time = Sep 18 2025 23:21:30 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="11" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6594</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32902716e-003</G>\n',
#    '#       <H>6.41296748e-004</H>\n',
#    '#       <I>2.24792144e-005</I>\n',
#    '#       <J>2.09037133e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5057</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02261783e+001</G>\n',
#    '#         <H>1.44216574e+000</H>\n',
#    '#         <I>-1.44249777e-003</I>\n',
#    '#         <J>1.83945074e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1467</SerialNumber>\n',
#    '#       <CalibrationDate>14-May-24</CalibrationDate>\n',
#    '#       <C1>-4.983324e+004</C1>\n',
#    '#       <C2>7.481707e-001</C2>\n',
#    '#       <C3>1.542490e-002</C3>\n',
#    '#       <D1>3.994200e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.011194e+001</T1>\n',
#    '#       <T2>-8.787910e-005</T2>\n',
#    '#       <T3>3.670550e-006</T3>\n',
#    '#       <T4>4.186210e-009</T4>\n',
#    '#       <Slope>0.99993591</Slope>\n',
#    '#       <Offset>-0.69285</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.279180e-002</AD590M>\n',
#    '#       <AD590B>-9.287340e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>6597</SerialNumber>\n',
#    '#       <CalibrationDate>31-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.32855123e-003</G>\n',
#    '#       <H>6.37888659e-004</H>\n',
#    '#       <I>2.15927206e-005</I>\n',
#    '#       <J>1.98472116e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>5058</SerialNumber>\n',
#    '#       <CalibrationDate>23-May-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.00121804e+001</G>\n',
#    '#         <H>1.38193094e+000</H>\n',
#    '#         <I>-1.38157249e-003</I>\n',
#    '#         <J>1.71223075e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4138</SerialNumber>\n',
#    '#       <CalibrationDate>05-Jun-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>5.2342e-001</Soc>\n',
#    '#         <offset>-0.5284</offset>\n',
#    '#         <A>-3.5144e-003</A>\n',
#    '#         <B> 1.6216e-004</B>\n',
#    '#         <C>-2.8601e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0300</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>4133</SerialNumber>\n',
#    '#       <CalibrationDate>30-May-24</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.1853e-001</Soc>\n',
#    '#         <offset>-0.7149</offset>\n',
#    '#         <A>-2.5264e-003</A>\n',
#    '#         <B> 2.5400e-005</B>\n',
#    '#         <C> 7.7465e-007</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.2100</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLRTD-6808</SerialNumber>\n',
#    '#       <CalibrationDate>6/3/2024</CalibrationDate>\n',
#    '#       <ScaleFactor>2.50000000e+001</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0320</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Logarithmic, Satlantic -->\n',
#    '#     <PARLog_SatlanticSensor SensorID="76" >\n',
#    '#       <SerialNumber>2146</SerialNumber>\n',
#    '#       <CalibrationDate>5/20/2024</CalibrationDate>\n',
#    '#       <a0>1.0656e+000</a0>\n',
#    '#       <a1>8.1157e-001</a1>\n',
#    '#       <Im>1.3589e+000</Im>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.0000e+000</Multiplier>\n',
#    '#     </PARLog_SatlanticSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Dec 22 2025 15:34:02, 7.26.7.129 [datcnv_vars = 9]\n',
#    '# datcnv_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.hex c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Dec 22 2025 15:34:04, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C prDM par/sat/log\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Dec 22 2025 15:34:04, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Dec 22 2025 15:34:04, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Dec 22 2025 15:34:05, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Dec 22 2025 15:34:05, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# split_date = Dec 22 2025 15:34:06, 7.26.7.129\n',
#    '# split_in = c:\\data\\ctd\\2025\\nw2501\\raw\\nw250145.cnv\n',
#    '# split_excl_bad_scans = yes\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 305,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'prDM',
#    8: 'par/sat/log',
#    9: 'flag'},
#   'SYSTEMtime': 'Sep 18 2025 23:21:30',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []}}

# %%
#this line adds available NMEA data to csv files for NRT/Preliminary erddap hosting... if there isn't an NMEA string, you will have to pull the locations
#  from the cast logs and output either a .nc or a more elaborate csv file furthur in to this process
NMEA_location = False
verbose = False
SYSTEMtime = True

if NMEA_location:
    
    for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['NMEAtime'],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1],
              cast.split('.')[0])
        if verbose:
            print(cruise_header[cast]['NMEAtime'],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1])
elif SYSTEMtime:
     for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['SYSTEMtime'],0,0,cast.split('.')[0])

# %%
#save downcast csv to file for viewing - really this is just a cleaned up cnv file
import pandas as pd
for cast in cruise_data.keys():
#     print(f'Processing Cast {cast}')
    cruise_data[cast]['time'] = pd.to_datetime(cruise_data[cast]['time'])
    cruise_data[cast].to_csv(sample_data_dir+cast.replace('cnv','csv'))

# %% [markdown]
# ## Post Cruise Processing with additional meta information

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'NW2501' #no hyphens
cruise_meta_file = sample_data_dir+'logs/NW2501.yaml'
inst_meta_file = sample_data_dir+'logs/EMA_standard_CTD.yaml'
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %% [markdown]
# ## Time Properties
#
# Not traditionally dealt with for CTD files as they are likely dynamically updated via GPS feed.  However, FOCI tends to label the date/time with the ***at depth*** time-stamp
#
# ## Depth Properties and other assumptions
#
# - currently, all processing and binning (1m for FOCI) is done via seabird routines and the windows software.  This may change with the python ctd package for a few tasks

# %% [markdown]
# ## Load all external meta information

# %%
#cruise info
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

#institutional info
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %%
inst_config
# Out:
# {'time': {'epic_key': 'TIM_601',
#   'name': 'time',
#   'generic_name': 'time',
#   'standard_name': 'time',
#   'long_name': 'date and time since reference time'},
#  'depth': {'epic_key': 'D_3',
#   'generic_name': 'depth',
#   'units': 'meter',
#   'long_name': 'depth below surface (meters)',
#   'standard_name': 'depth',
#   'positive': 'down'},
#  'latitude': {'epic_key': 'LON_501',
#   'name': 'latitude',
#   'generic_name': 'latitude',
#   'units': 'degrees_north',
#   'long_name': 'latitude',
#   'standard_name': 'latitude'},
#  'longitude': {'epic_key': 'LAT_500',
#   'name': 'longitude',
#   'generic_name': 'longitude',
#   'units': 'degrees_east',
#   'long_name': 'longitude',
#   'standard_name': 'longitude'},
#  'temperature_ch1': {'epic_key': 'T_28',
#   'generic_name': 'temp channel 1',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'temperature_ch2': {'epic_key': 'T2_35',
#   'generic_name': 'temp channel 2',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'pressure': {'epic_key': 'P_1',
#   'generic_name': 'pres',
#   'units': 'decibar',
#   'long_name': 'Sea water pressure, equals 0 at sea-level',
#   'standard_name': 'sea_water_pressure_due_to_sea_water'},
#  'salinity_ch1': {'epic_key': 'S_41',
#   'generic_name': 'psal channel 1',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'salinity_ch2': {'epic_key': 'S_42',
#   'generic_name': 'psal channel 2',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'chlor_fluorescence': {'epic_key': 'F_903',
#   'generic_name': 'chlor_fluorescence',
#   'long_name': 'Mass Concdentration of chlorophyll from chlorophyll fluorescence',
#   'standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#   'units': 'ugrams/l'},
#  'turbidity': {'epic_key': 'Trb_980',
#   'generic_name': 'Turbidity',
#   'long_name': 'Turbidity of ocean water in Nephlometric Turbidity Units',
#   'standard_name': 'sea_water_turbidity',
#   'units': 'NTU'},
#  'par': {'generic_name': 'par',
#   'epic_key': 'PAR_905',
#   'long_name': 'Photosynthetic Active Radiation',
#   'standard_name': 'omnidirectional_photosynthetic_photon_spherical_irradiance_in_sea_water',
#   'units': 'uEin cm-2 s-1',
#   'comments': 'satlantic log-PAR'},
#  'oxy_conc_ch1': {'generic_name': 'oxy_conc channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_conc_ch2': {'generic_name': 'oxy_conc channel 2',
#   'epic_key': 'CTDOXY_4221',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_concM_ch1': {'generic_name': 'oxy_concM channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_concM_ch2': {'generic_name': 'oxy_concM channel 2',
#   'epic_key': 'O_2060',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_percentsat_ch1': {'generic_name': 'oxy_psat channel 1',
#   'epic_key': 'OST_62',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'oxy_percentsat_ch2': {'generic_name': 'oxy_psat channel 2',
#   'epic_key': 'CTDOST_4220',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'}}

# %%
cruise_config['CTDCasts']['CTD001']
# Out:
# {'id': 55394,
#  'Vessel': 'NorthWest Explorer',
#  'CruiseID': 'NW2501',
#  'Project_Leg': '',
#  'UniqueCruiseID': 'NW2501',
#  'Project': 'NBS',
#  'StationNo_altname': '1',
#  'ConsecutiveCastNo': 'CTD001',
#  'LatitudeDeg': 60,
#  'LatitudeMin': 0.69,
#  'LongitudeDeg': 167,
#  'LongitudeMin': 59.046,
#  'GMTDay': 2,
#  'GMTMonth': 'Sep',
#  'GMTYear': 2025,
#  'GMTTime': 83672,
#  'DryBulb': -99.9,
#  'RelativeHumidity': -999,
#  'WetBulb': -99.9,
#  'Pressure': '',
#  'SeaState': '',
#  'Visibility': '',
#  'WindDir': -999,
#  'WindSpd': -99.9,
#  'CloudAmt': '',
#  'CloudType': '',
#  'Weather': '',
#  'SurfaceTemp': -99.9,
#  'BottomDepth': 24,
#  'StationNameID': '',
#  'MaxDepth': -9999,
#  'InstrumentSerialNos': '',
#  'Notes': 'pump not working, collected water, but ctd data not good',
#  'NutrientBtlNiskinNo': '',
#  'NutrientBtlNumbers': '',
#  'OxygenBtlNiskinNo': '',
#  'OxygenBtlNumbers': '',
#  'SalinityBtlNiskinNo': '',
#  'SalinityBtlNumbers': '',
#  'ChlorophyllBtlNiskinNo': '',
#  'ChlorophyllBtlVolumes': '',
#  'InstrumentType': 'SBE911plus',
#  'WaterMassCode': '',
#  'isMooringProfileCast': 'n',
#  'MooringID': '',
#  'QualityControlled': 'n',
#  'FileName': "''\r"}

# %%
cruise_data['ctd001.cnv'].columns
# Out:
# Index(['c0mS/cm', 'c1mS/cm', 'flECO-AFL', 'sbeox0V', 'sbeox1V', 't090C',
#        't190C', 'par/sat/log', 'sal00', 'sal11', 'sbeox0Mg/L', 'sbeox0PS',
#        'sbox0Mm/Kg', 'sbeox1Mg/L', 'sbeox1PS', 'sbox1Mm/Kg', 'sigma-t00',
#        'sigma-t11', 'nbin', 'flag'],
#       dtype='object')

# %%
cast = 'ctd001.cnv'

cruise_data[cast] = cruise_data[cast].rename(columns={
                    't090C':'temperature_ch1',
                    't190C':'temperature_ch2',
                    'sal00':'salinity_ch1',
                    'sal11':'salinity_ch2',
                    'sbox0Mm/Kg':'oxy_conc_ch1',
                    'sbeox0ML/L':'oxy_concM_ch1',
                    'sbeox0PS':'oxy_percentsat_ch1',
                    'sbox1Mm/Kg':'oxy_conc_ch2',
                    'sbeox1ML/L':'oxy_concM_ch2',
                    'sbeox1PS':'oxy_percentsat_ch2',
                    'sigma-t00':'sigma_t_ch1',
                    'sigma-t11':'sigma_t_ch2',
                    'flECO-AFL':'chlor_fluorescence',
                    'turbWETntu0':'turbidity',
                    'cstarat0':'Attenuation',
                    'cstartr0':'Transmittance',
                    'par':'par',
                    'par/sat/log':'par',
                    'empty':'empty', #this will be ignored
                    'flag':'flag'})

cruise_data[cast].index.rename('depth',inplace=True)
#cruise_data[cast].sample()

cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                            instrument_yaml=inst_config, 
                            operation_yaml=cruise_config,
                            operation_type='ctd')
cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

#interp to sfc for list of vars
try:
    cruise_data_nc.interp2sfc(novars=['par'])
except:
    pass

#add global attributes
cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
cruise_data_nc.get_xdf()

#add instituitonal global attributes
cruise_data_nc.institution_meta_add(group_config)

#add creation date/time - provenance data
cruise_data_nc.provinance_meta_add()

#provide intial qc status field
cruise_data_nc.qc_status(qc_status='unknown')

cast_label = cast.split('.')[0].split('d')[-1]
cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                        filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
#generate editable csv files
to_edit = True
if to_edit:
    if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
        cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')

# %%
for cast in cruise_data.keys():
    print(f'Processing Cast {cast}')
    try:
        #output cruise cast stats here
        #cruise_data[cast].describe()
        #cruise_data['ctd001.cnv'].hist() - seaborn may have a better summary plot than just a bunch of histograms
        #sns.pairplot(cruise_data[cast])

        cruise_data[cast] = cruise_data[cast].rename(columns={
                            't090C':'temperature_ch1',
                            't190C':'temperature_ch2',
                            'sal00':'salinity_ch1',
                            'sal11':'salinity_ch2',
                            'sbox0Mm/Kg':'oxy_conc_ch1',
                            'sbeox0ML/L':'oxy_concM_ch1',
                            'sbeox0PS':'oxy_percentsat_ch1',
                            'sbox1Mm/Kg':'oxy_conc_ch2',
                            'sbeox1ML/L':'oxy_concM_ch2',
                            'sbeox1PS':'oxy_percentsat_ch2',
                            'sigma-t00':'sigma_t_ch1',
                            'sigma-t11':'sigma_t_ch2',
                            'flECO-AFL':'chlor_fluorescence',
                            'turbWETntu0':'turbidity',
                            'cstarat0':'Attenuation',
                            'cstartr0':'Transmittance',
                            'par':'par',
                            'par/sat/log':'par',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data[cast].index.rename('depth',inplace=True)
        #cruise_data[cast].sample()

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                    instrument_yaml=inst_config, 
                                    operation_yaml=cruise_config,
                                    operation_type='ctd')
        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
        cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

        #interp to sfc for list of vars
        try:
            cruise_data_nc.interp2sfc(novars=['par'])
        except:
            pass

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
        cruise_data_nc.get_xdf()

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='unknown')

        cast_label = cast.split('.')[0].split('d')[-1]
        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
        #generate editable csv files
        to_edit = True
        if to_edit:
            if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
                cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')  
        
    except:
       print('Conversion Failed')
# Out:
# Processing Cast ctd001.cnv
# Processing Cast ctd002.cnv
# Processing Cast ctd003.cnv
# Processing Cast ctd004.cnv
# Processing Cast ctd005.cnv
# Processing Cast ctd006.cnv
# Processing Cast ctd007.cnv
# Processing Cast ctd008.cnv
# Processing Cast ctd009.cnv
# Processing Cast ctd010.cnv
# Processing Cast ctd011.cnv
# Processing Cast ctd012.cnv
# Processing Cast ctd013.cnv
# Processing Cast ctd014.cnv
# Processing Cast ctd015.cnv
# Processing Cast ctd016.cnv
# Processing Cast ctd017.cnv
# Processing Cast ctd018.cnv
# Processing Cast ctd019.cnv
# Processing Cast ctd020.cnv
# Processing Cast ctd021.cnv
# Processing Cast ctd022.cnv
# Processing Cast ctd023.cnv
# Processing Cast ctd024.cnv
# Processing Cast ctd025.cnv
# Processing Cast ctd026.cnv
# Processing Cast ctd027.cnv
# Processing Cast ctd028.cnv
# Processing Cast ctd029.cnv
# Processing Cast ctd030.cnv
# Processing Cast ctd031.cnv
# Processing Cast ctd032.cnv
# Processing Cast ctd033.cnv
# Processing Cast ctd034.cnv
# Processing Cast ctd035.cnv
# Processing Cast ctd036.cnv
# Processing Cast ctd037.cnv
# Conversion Failed
# Processing Cast ctd038.cnv
# Processing Cast ctd039.cnv
# Processing Cast ctd040.cnv
# Processing Cast ctd041.cnv
# Processing Cast ctd042.cnv
# Processing Cast ctd043.cnv
# Processing Cast ctd044.cnv
# Processing Cast ctd045.cnv
# Conversion Failed
# Processing Cast dctd001.cnv
# Conversion Failed
# Processing Cast dctd002.cnv
# Conversion Failed
# Processing Cast dctd003.cnv
# Conversion Failed
# Processing Cast dctd004.cnv
# Conversion Failed
# Processing Cast dctd005.cnv
# Conversion Failed
# Processing Cast dctd006.cnv
# Conversion Failed
# Processing Cast dctd007.cnv
# Conversion Failed
# Processing Cast dctd008.cnv
# Conversion Failed
# Processing Cast dctd009.cnv
# Conversion Failed
# Processing Cast dctd010.cnv
# Conversion Failed
# Processing Cast dctd011.cnv
# Conversion Failed
# Processing Cast dctd012.cnv
# Conversion Failed
# Processing Cast dctd013.cnv
# Conversion Failed
# Processing Cast dctd014.cnv
# Conversion Failed
# Processing Cast dctd015.cnv
# Conversion Failed
# Processing Cast dctd016.cnv
# Conversion Failed
# Processing Cast dctd017.cnv
# Conversion Failed
# Processing Cast dctd018.cnv
# Conversion Failed
# Processing Cast dctd019.cnv
# Conversion Failed
# Processing Cast dctd020.cnv
# Conversion Failed
# Processing Cast dctd021.cnv
# Conversion Failed
# Processing Cast dctd022.cnv
# Conversion Failed
# Processing Cast dctd023.cnv
# Conversion Failed
# Processing Cast dctd024.cnv
# Conversion Failed
# Processing Cast dctd025.cnv
# Conversion Failed
# Processing Cast dctd026.cnv
# Conversion Failed
# Processing Cast dctd027.cnv
# Conversion Failed
# Processing Cast dctd028.cnv
# Conversion Failed
# Processing Cast dctd029.cnv
# Conversion Failed
# Processing Cast dctd030.cnv
# Conversion Failed
# Processing Cast dctd031.cnv
# Conversion Failed
# Processing Cast dctd032.cnv
# Conversion Failed
# Processing Cast dctd033.cnv
# Conversion Failed
# Processing Cast dctd034.cnv
# Conversion Failed
# Processing Cast dctd035.cnv
# Conversion Failed
# Processing Cast dctd036.cnv
# Conversion Failed
# Processing Cast dctd037.cnv
# Conversion Failed
# Processing Cast dctd038.cnv
# Conversion Failed
# Processing Cast dctd039.cnv
# Conversion Failed
# Processing Cast dctd040.cnv
# Conversion Failed
# Processing Cast dctd041.cnv
# Conversion Failed
# Processing Cast dctd042.cnv
# Conversion Failed
# Processing Cast dctd043.cnv
# Conversion Failed
# Processing Cast dctd044.cnv
# Conversion Failed
# Processing Cast dctd045.cnv
# Conversion Failed
# Processing Cast uctd001.cnv
# Conversion Failed
# Processing Cast uctd002.cnv
# Conversion Failed
# Processing Cast uctd003.cnv
# Conversion Failed
# Processing Cast uctd004.cnv
# Conversion Failed
# Processing Cast uctd005.cnv
# Conversion Failed
# Processing Cast uctd006.cnv
# Conversion Failed
# Processing Cast uctd007.cnv
# Conversion Failed
# Processing Cast uctd008.cnv
# Conversion Failed
# Processing Cast uctd009.cnv
# Conversion Failed
# Processing Cast uctd010.cnv
# Conversion Failed
# Processing Cast uctd011.cnv
# Conversion Failed
# Processing Cast uctd012.cnv
# Conversion Failed
# Processing Cast uctd013.cnv
# Conversion Failed
# Processing Cast uctd014.cnv
# Conversion Failed
# Processing Cast uctd015.cnv
# Conversion Failed
# Processing Cast uctd016.cnv
# Conversion Failed
# Processing Cast uctd017.cnv
# Conversion Failed
# Processing Cast uctd018.cnv
# Conversion Failed
# Processing Cast uctd019.cnv
# Conversion Failed
# Processing Cast uctd020.cnv
# Conversion Failed
# Processing Cast uctd021.cnv
# Conversion Failed
# Processing Cast uctd022.cnv
# Conversion Failed
# Processing Cast uctd023.cnv
# Conversion Failed
# Processing Cast uctd024.cnv
# Conversion Failed
# Processing Cast uctd025.cnv
# Conversion Failed
# Processing Cast uctd026.cnv
# Conversion Failed
# Processing Cast uctd027.cnv
# Conversion Failed
# Processing Cast uctd028.cnv
# Conversion Failed
# Processing Cast uctd029.cnv
# Conversion Failed
# Processing Cast uctd030.cnv
# Conversion Failed
# Processing Cast uctd031.cnv
# Conversion Failed
# Processing Cast uctd032.cnv
# Conversion Failed
# Processing Cast uctd033.cnv
# Conversion Failed
# Processing Cast uctd034.cnv
# Conversion Failed
# Processing Cast uctd035.cnv
# Conversion Failed
# Processing Cast uctd036.cnv
# Conversion Failed
# Processing Cast uctd037.cnv
# Conversion Failed
# Processing Cast uctd038.cnv
# Conversion Failed
# Processing Cast uctd039.cnv
# Conversion Failed
# Processing Cast uctd040.cnv
# Conversion Failed
# Processing Cast uctd041.cnv
# Conversion Failed
# Processing Cast uctd042.cnv
# Conversion Failed
# Processing Cast uctd043.cnv
# Conversion Failed
# Processing Cast uctd044.cnv
# Conversion Failed
# Processing Cast uctd045.cnv
# Conversion Failed

# %% [markdown]
# ## QC Next Steps

# %%
import EcoFOCIpy.plots.sbe_ctd_plots as sbe_ctd_plots
import os
import xarray as xa
import seaborn as sns
import numpy as np

# %%
sample_data_dir = '/Users/bell/ecoraid/2025/CTDcasts/nw2501/working/' #root path to cruise directory working repo

# %% [markdown]
# ### QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status for the file and the history for future steps
# - from NRT csv files... make edits then use that to modify netcdf?
# - **Better Yet** export netcdf files with variable flags to csv and edit then reingest and modify
#     - modify netcdf in place and provide a qcflag?
#
#
# ### Likely first edits
# - research issues noted in cruise logs
# - remove failed instrument (clogs, or other challenges that arent correctable)
# - extrapolate to sfc (not par though)
# - despike depths (interpolate between depths)
# - check for common issues
#     - lags in salinity when going through interface

# %%
#test for salinity bottle run needs
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        try:
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            saldiff = cruise_data_nc.salinity_ch1 - cruise_data_nc.salinity_ch2
            print(f"{cast}: Profile Averaged Salinity Difference,STD (chan1-chan2){saldiff.mean().values},{saldiff.std().values}")        
            saldiff.plot.hist(bins=50,xlim=[-.005,.005])
        except:
            print(f"{cast}: less than two salinity channels")
# Out:
# NW2501c019_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0038399999999995773,0.005973307291609688
# NW2501c043_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.14888999999999938,0.2422993518356989
# NW2501c045_ctd.nc: less than two salinity channels

# %%
# Following routines will eventually get ported to ecofocipy as subroutines to be called

import seawater as sw

def sigmat_update(salinity=None,temperature=None):
    '''
    Changes to T or S (commonly to despike values or apply a salinity offset) will need corresponding changes in sigmat
    '''
    # calculate sigmaT at 0db gauge pressure (s, t, p=0)
    sigt = (sw.eos80.dens0(s=salinity, t=temperature) - 1000)
    
    return sigt

# %% [markdown]
# ## Generate Plots
#
#
# ### Make General Plots
# - 1:1 plots for paired instruments for each cast (tells if a sensor failed)
# - TS_Sigmat, Chlor/Par/Turb, Oxy,Temp
# - T/S property property plot
# - upcast/downcast plt

# %%
calc_sigmat = True

for cast in sorted(os.listdir(sample_data_dir)):
    try:
        if cast.endswith('.nc'):
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            ctd_df = cruise_data_nc.to_dataframe()
            
            if calc_sigmat:
                #update sigmat (or calculate it I suppose)
                sigup = sigmat_update(salinity=ctd_df.salinity_ch1,
                                      temperature=ctd_df.temperature_ch1)
                ctd_df['sigma_t_ch1'] = sigup
                
                sigup2 = sigmat_update(salinity=ctd_df.salinity_ch2,
                                      temperature=ctd_df.temperature_ch2)
                ctd_df['sigma_t_ch2'] = sigup2   
            sbe_p = sbe_ctd_plots.CTDProfilePlot()
            plt,fig =sbe_p.plot3var(varname=['temperature_ch1','temperature_ch2','salinity_ch1','salinity_ch2','sigma_t_ch1','sigma_t_ch2'],
                              xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.salinity_ch1,ctd_df.salinity_ch2,ctd_df.sigma_t_ch1,ctd_df.sigma_t_ch2],
                              ydata=ctd_df.index.get_level_values('depth'),
                              secondary=True,
                              xlabel=['Temperature','Salinity','Sigma-T'])
    
            DefaultSize = fig.get_size_inches()
            fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
            plt.savefig(sample_data_dir+cast.replace('.nc','_TempSalSigmat.png'))
            plt.close(fig)
    except:
        print(f'{cast} failed to plot')
# Out:
# NW2501c045_ctd.nc failed to plot

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    try:
        if cast.endswith('.nc'):
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            ctd_df = cruise_data_nc.to_dataframe()
            
            sbe_p = sbe_ctd_plots.CTDProfilePlot()
            plt,fig =sbe_p.plot2var(varname=['temperature_ch1','temperature_ch2','oxy_percentsat_ch1','oxy_percentsat_ch2'],
                              xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.oxy_percentsat_ch1,ctd_df.oxy_percentsat_ch2],
                              ydata=ctd_df.index.get_level_values('depth'),
                              secondary=True,
                              xlabel=['Temperature','Oxygen Saturation'])
    
            DefaultSize = fig.get_size_inches()
            fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
            plt.savefig(sample_data_dir+cast.replace('.nc','_TempOxy.png'))
            plt.close(fig)
    except:
        print(f'{cast} failed to plot')
# Out:
# NW2501c045_ctd.nc failed to plot

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    try:
        if cast.endswith('.nc'):
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            ctd_df = cruise_data_nc.to_dataframe()
            
            sbe_p = sbe_ctd_plots.CTDProfilePlot()
            plt,fig =sbe_p.plot2var(varname=['chlor_fluorescence','','par'],
                              xdata=[ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
                              ydata=ctd_df.index.get_level_values('depth'),
                              secondary=False,
                              xlabel=['Fluor','Par'])
    
            DefaultSize = fig.get_size_inches()
            fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
            plt.savefig(sample_data_dir+cast.replace('.nc','_TurbFluorPAR.png'))
            plt.close(fig)
    except:
        print(f'{cast} failed to plot')
# Out:
# NW2501c045_ctd.nc failed to plot
